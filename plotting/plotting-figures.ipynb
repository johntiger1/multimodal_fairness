# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
single_model_fair = pd.read_csv("plotting_data/single_model_mort_fairness.csv")

# %%
list(single_model_fair.iloc[0])
# Out:
# [0.03549271543, 0.008318021982, 0.010422963620000001]

# %%
ensemble_model_fair = pd.read_csv("plotting_data/ensemble_model_mort_fairness.csv")

# %%
groups = ["mortality", "decompensation", "phenotyping"]
x = np.arange(len(groups))  # the label locations
width = 0.35  # the width of the bars

# %%
fig, ax  = plt.subplots()
fig.set_size_inches(6, 6, forward=True)
rects1 = ax.bar(x - width/2, list(single_model_fair.iloc[0]), width, label='Text model')
rects2 = ax.bar(x + width/2, list(ensemble_model_fair.iloc[0]), width, label='Ensemble model')
ax.set_xticks(x)
ax.set_xticklabels(groups)
ax.set_ylabel("Worst Gap in Classifier AUC performance")
ax.set_xlabel("Clinical Prediction Task")
ax.set_title("Classifier performance disparity based \non protected attribute: ETHNICITY")
ax.legend()

# %%
fig.savefig("generalization_fairness.png")

# %%
single_model_perf = pd.read_csv("plotting_data/single_model_mort_performance.csv")
ensemble_model_perf = pd.read_csv("plotting_data/ensemble_model_mort_performance.csv")

# %%
fig, ax  = plt.subplots()
fig.set_size_inches(6, 6, forward=True)
rects1 = ax.bar(x - width/2, list(single_model_perf.iloc[0]), width, label='Text model')
rects2 = ax.bar(x + width/2, list(ensemble_model_perf.iloc[0]), width, label='Ensemble model')
ax.set_xticks(x)
ax.set_xticklabels(groups)
ax.set_ylabel("Worst Gap in Classifier AUC performance")
ax.set_xlabel("Clinical Prediction Task")
ax.set_title("Classifier performance disparity based \non protected attribute: ETHNICITY")
ax.legend()
